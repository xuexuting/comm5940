# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time
# quote_page = requests.get('https://www.discuss.com.hk/forumdisplay.php?fid=40&page=1')
# soup = BeautifulSoup(quote_page.text,'html.parser')
header = ['page #','title','url']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
   quote_page = requests.get('https://www.discuss.com.hk/forumdisplay.php?fid=250&page='+str(i))
   sleep(randint(8,15))
   print("\n***** Page " + str(i) +" in action *****")
   soup = BeautifulSoup(quote_page.content,'html.parser')
   for article in soup.find_all("span", attrs={"class":"tsubject"}):
   # for article in soup.find_all('span',class_='tsubject'):
           page_no = str(i)
           title = article.a.text.encode('utf-8').strip()
           decoded_title = title.decode('utf-8')
           url = article.a.get('href')  
           print(decoded_title)
           print('https://www.discuss.com.hk/'+url)
           data.append((page_no, decoded_title, 'https://www.discuss.com.hk/'+url))
df = pd.DataFrame(data,
columns = header
)
df.to_csv('ProblemSet2V1.csv', sep='\t', encoding='utf-8')
# Out:
# ***** Page 1 in action *****
# 徵求種子小苗區
# https://www.discuss.com.hk/viewthread.php?tid=1407517&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 種子/植物自由交換/送贈廣場
# https://www.discuss.com.hk/viewthread.php?tid=1407453&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 園藝分享心得 - 得閒吹水聊天室（69)
# https://www.discuss.com.hk/viewthread.php?tid=27949524&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 怎樣貼出花兒靚相
# https://www.discuss.com.hk/viewthread.php?tid=23325251&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 親親大自然-有機耕作
# https://www.discuss.com.hk/viewthread.php?tid=1269007&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# [轉貼]園藝基本六大"常識"
# https://www.discuss.com.hk/viewthread.php?tid=1502693&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 會議室
# https://www.discuss.com.hk/viewthread.php?tid=25685591&extra=page%3D1&tr_h=16077172415c652118e0d0c5_10471967
# 2019情人節 最後一睇 拍拖好去處
# ...

# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time
# quote_page = requests.get('https://www.discuss.com.hk/forumdisplay.php?fid=40&page=1')
# soup = BeautifulSoup(quote_page.text,'html.parser')
header = ['page #','author','postdate']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
   quote_page = requests.get('https://www.discuss.com.hk/forumdisplay.php?fid=250&page='+str(i))
   sleep(randint(8,15))
   print("\n***** Page " + str(i) +" in action *****")
   soup = BeautifulSoup(quote_page.content,'html.parser')
   for article in soup.find_all("td", attrs={"class":"author"}):
   # for article in soup.find_all('td',class='author'):
           page_no = str(i)
           author = article.a
           date = article.em
           print(author)
           print(date)
           data.append((page_no, author,date))
df = pd.DataFrame(data,
columns = header
)
df.to_csv('ProblemSet2V2.csv', sep='\t', encoding='utf-8')
# Out:
# ***** Page 1 in action *****
# None
# None
# <a href="space.php?action=viewpro&amp;uid=6074869">mhmimi</a>
# <em>2017-11-14</em>
# <a href="space.php?action=viewpro&amp;uid=289822">辟易</a>
# <em>2006-4-19</em>
# <a href="space.php?action=viewpro&amp;uid=289822">辟易</a>
# <em>2006-4-19</em>
# <a href="space.php?action=viewpro&amp;uid=2267944">呆頭鳥</a>
# <em>2019-1-3</em>
# <a href="space.php?action=viewpro&amp;uid=3860925">A10</a>
# <em>2014-5-26</em>
# <a href="space.php?action=viewpro&amp;uid=805276">himalayan</a>
# <em>2006-3-20</em>
# <a href="space.php?action=viewpro&amp;uid=805276">himalayan</a>
# <em>2006-5-10</em>
# <a href="space.php?action=viewpro&amp;uid=3738964">晴朗之子</a>
# <em>2016-4-6</em>
# <a href="/space.php?action=viewpro&amp;uid=5710924">hanabi221</a>
# <em>2019-2-14</em>
# <a href="/space.php?action=viewpro&amp;uid=5351603">thanks橋</a>
# <em>2019-2-13</em>
# <a href="/space.php?action=viewpro&amp;uid=5266468">信的戀人</a>
# <em>2019-2-14</em>
# None
# <em> </em>
# ...
